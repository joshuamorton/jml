# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from utils import circles

# %%
import imp
imp.reload(circles)
# Out:
# <module 'utils.circles' from '/home/joshua/Dropbox/code/jml/experiments/utils/circles.py'>

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.animation as animation
from IPython.display import HTML

fig = plt.figure()
im = plt.imshow(circles.random_boxed_circle(20,20,8)[0], animated=True)

def updatefig(*args):
    im.set_array(circles.random_boxed_circle(20,20,8)[0])
    return im,

anim = animation.FuncAnimation(fig, updatefig, interval=100, blit=True)
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
